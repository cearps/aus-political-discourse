# %% [markdown]
# # 01 - Ingestion\n\nFetch a sample HTML page and save it to `data/raw/`.

# %%
from src.ingest import fetch_html, save_raw_html\n\n# Placeholder URL (replace with a Hansard page when ready)\nurl = "https://example.com"\n\nhtml = fetch_html(url)\npath = save_raw_html(html, "sample.html")\n\nprint(f"Saved to: {path}")\nprint(html[:1000])
